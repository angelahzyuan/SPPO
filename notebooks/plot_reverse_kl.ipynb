# %% [markdown]
# # Plot reverse KL experiment results

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
vanilla = [[26.36, 24.04, 1802],
[29.44, 29.27, 1984],
[28.16, 30.12, 2292],
[30.05, 33.13, 2700],
[27.74, 30.23, 2712],
[26.68, 30.20, 2806]]

kl_01 = [[26.84, 24.13, 1780],
[27.05, 27.41, 2022],
[30.36, 31.98, 2269],
[30.93, 33.01, 2609],
[32.77, 35.69, 2191],
[30.38, 34.87, 2409]]

kl_001 = [[25.55, 23.42, 1788],
[26.82, 26.15, 1919],
[27.00, 27.87, 2205],
[29.25, 30.78, 2839],
[28.99, 32.63, 2859],
[26.10, 29.83, 2754]]

vanilla = np.array(vanilla)
kl_01 = np.array(kl_01)
kl_001 = np.array(kl_001)

# %%
plt.plot(vanilla[:,2], vanilla[:,0], 'o-', label='SPPO')
plt.plot(kl_01[:,2], kl_01[:,0], 'o-', label='SPPO-ReverseKL (0.1)')
plt.plot(kl_001[:,2], kl_001[:,0], 'o-', label='SPPO-ReverseKL (0.01)')
plt.text(1750, 27.5, 'Iter1', fontsize=12, color='black')
plt.xlabel('Response Length')
plt.ylabel('Alpaca LCWR')
plt.legend()
plt.show()
